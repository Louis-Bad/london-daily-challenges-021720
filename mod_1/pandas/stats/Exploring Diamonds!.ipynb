# %% [markdown]
# ## Exploring Descriptive Statistics

# %% [markdown]
# Use the following dataset to answer the questions about the **diamonds** dataset.

# %%
# Run this cell without changes
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !ls ../pandas-202/
# Out:
# diamonds.csv index.ipynb

# %%
# Run this cell without changes
df = pd.read_csv('../pandas-202/diamonds.csv')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# **1) What are the mean carat and the median carat for the each group of color in this dataset?**

# %%
# Code here to find the mean carat and median carat
df.groupby(['color']).describe()
# Out:
#          carat                                                       depth  \
#          count      mean       std   min   25%   50%    75%   max    count
# color
# D       6775.0  0.657795  0.359573  0.20  0.36  0.53  0.905  3.40   6775.0
# E       9797.0  0.657867  0.368566  0.20  0.36  0.53  0.900  3.05   9797.0
# F       9542.0  0.736538  0.397588  0.20  0.40  0.70  1.010  3.01   9542.0
# G      11292.0  0.771190  0.441436  0.23  0.39  0.70  1.040  3.01  11292.0
# H       8304.0  0.911799  0.521236  0.23  0.41  0.90  1.200  4.13   8304.0
# I       5422.0  1.026927  0.579173  0.23  0.52  1.00  1.500  4.01   5422.0
# J       2808.0  1.162137  0.595801  0.23  0.71  1.11  1.520  5.01   2808.0
#
#                   ...         y               z                            \
#             mean  ...       75%    max    count      mean       std   min
# color             ...
# D      61.698125  ...    6.1800   9.34   6775.0  3.342827  0.578527  0.00
# ...

# %% [markdown]
# In your own words, how are the mean and median related to each other and what do these values tell us about the distribution of the variable 'Age'

# %% [markdown]
# ### Your written answer here
# The mean and median are both measures of central tendancy. Although there is no variable age in thsi data set, if we were to see a descrepancy between the median and mean of a data set it is a sign that the data is not normally distributed

# %% [markdown]
# **2) Arrange the table so that the diamonds with the highest carats are listed first.**

# %%
# Code here 
df.sort_values(['carat'], ascending=False)
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13       Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 26444   4.00  Very Good     I      I1   63.3   58.0  15984  10.01   9.94  6.31
# 26534   3.67    Premium     I      I1   62.4   56.0  16193   9.86   9.81  6.13
# 23644   3.65       Fair     H      I1   67.1   53.0  11668   9.53   9.48  6.38
# 27679   3.51    Premium     J     VS2   62.5   59.0  18701   9.66   9.63  6.03
# 24328   3.50      Ideal     H      I1   62.8   57.0  12587   9.65   9.59  6.03
# 26431   3.40       Fair     D      I1   66.8   52.0  15964   9.42   9.34  6.27
# ...

# %% [markdown]
# **BONUS 1: Use the seaborn library to make a scatter plot between carat and depth, carat and table, carat and price. Use the hue argument to group by either color or cut**

# %%
# Your code here! 
sns.scatterplot(data=df, x='depth', y='carat', hue='color');

# %%
sns.scatterplot(data=df, x='table', y='carat', hue='color');

# %%
sns.scatterplot(data=df, x='price', y='carat', hue='color');

# %% [markdown]
# **BONUS 2: Calculate the correlation coeffecient between each continuous variable in this dataset.**

# %%
# Your code here!
df.corr(method='pearson', min_periods=10)
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %% [markdown]
# **BONUS 3: Interpret each correlation coeffecient. Refer to your READMEs, Labs, or external literature if needed!**

# %% [markdown]
# #### A few simple observations:
# - Not surprisingly carat is seemimgly the best predictor of daimond price with a very high R value
# - Depth doesn't seem to have a strong correlation with any of the variables in the data set
# - The x, y and z variables seem to be very closely related to each other, fluctuating in similar ways when compared to the other variables in the data set. This could be a sign that they are measuring very similar things or maybe even that there is a cofounding factor that they are each related to
